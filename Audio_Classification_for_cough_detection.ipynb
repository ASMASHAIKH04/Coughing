# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = '/content/drive/My Drive/coughing'

# %% [markdown]
# Required Libraries

# %%
pip install numpy pandas librosa matplotlib tensorflow scikit-learn
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
pip install pydub
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import soundfile as sf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from pathlib import Path
from tensorflow.keras.utils import to_categorical

# %%
import os
from pathlib import Path

try:
    from pydub import AudioSegment
except ModuleNotFoundError:
    # !pip install pydub
    from pydub import AudioSegment

# Function to convert mp3 to wav and count errors
def convert_mp3_to_wav(mp3_file, output_folder):
    try:
        # Load mp3 file
        audio = AudioSegment.from_mp3(mp3_file)

        # Define output wav file path
        wav_file = os.path.join(output_folder, Path(mp3_file).stem + '.wav')

        # Export as wav
        audio.export(wav_file, format="wav")

        print(f"Converted {mp3_file} to {wav_file}")
        return False  # No error
    except Exception as e:
        print(f"Error converting {mp3_file}: {e}")
        return True  # Error occurred

# Function to recursively find mp3 files and convert them, counting errors
def count_files_with_errors(folder_path, output_folder):
    error_count = 0
    files_with_errors = []

    for root, _, files in os.walk(folder_path):
        for file_name in files:
            if file_name.lower().endswith('.mp3'):
                mp3_file = os.path.join(root, file_name)
                if convert_mp3_to_wav(mp3_file, output_folder):
                    error_count += 1
                    files_with_errors.append(mp3_file)

    print(f"Total files with .wav conversion problems: {error_count}")
    if error_count > 0:
        print("Files with errors:")
        for file in files_with_errors:
            print(file)

# Main function
def main():
    folder_path = '/content/drive/MyDrive/coughing'  # Update to the correct path
    output_folder = '/content/drive/MyDrive/coughing/wav_files'  # Output folder for wav files

    # Create output folder if it doesn't exist
    Path(output_folder).mkdir(parents=True, exist_ok=True)

    # Count files with conversion errors
    count_files_with_errors(folder_path, output_folder)

if __name__ == "__main__":
    main()
# Out:
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_3-01.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_3-01.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_2-01.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_2-01.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_13-03.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_13-03.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_1A-03.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_1A-03.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_1B-04.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_1B-04.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_1C-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_1C-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_1D-04.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_1D-04.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_1-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_1-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_4-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_4-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_2-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_2-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_6-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_6-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_5-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_5-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_3-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_3-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_11-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_11-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_9-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_9-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_13-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_13-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_7-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_7-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_8-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_8-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_12-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_12-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_10-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_10-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_4_clip_14-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_4_clip_14-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_5_clip_1-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_5_clip_1-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_5_clip_2-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_5_clip_2-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_6.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_6.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_1-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_1-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_2-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_2-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_4-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_4-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_5-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_5-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_6-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_6-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_7-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_7-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_9-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_9-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_10-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_10-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_3-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_3-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_7_clip_8-02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_7_clip_8-02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_8A-04.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_8A-04.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_8B-04.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_8B-04.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_8C-04.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_8C-04.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_20_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_20_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_18_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_18_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_11_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_11_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_16_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_16_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_17_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_17_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_14_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_14_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_15_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_15_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_19_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_19_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_12_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_12_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_9_clip_13_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_9_clip_13_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_12_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_12_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_11_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_11_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_19_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_19_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_20_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_20_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_14_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_14_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_16_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_16_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_15_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_15_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_17_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_17_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_13_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_13_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_10_clip_18_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_10_clip_18_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_12_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_12_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_12_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_12_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_12_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_12_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_12_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_12_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_12_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_12_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_12_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_12_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_14_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_14_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_14_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_14_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_14_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_14_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_15_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_15_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_15_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_15_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_15_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_15_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_15_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_15_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_15_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_15_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_16_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_16_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_16_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_16_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_16_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_16_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_16_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_16_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_16_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_16_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_16_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_16_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_11_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_11_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_11_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_11_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_11_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_11_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_11_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_11_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_11_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_11_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_11_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_11_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_11_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_11_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/mild_coughing/mild_coughing_17_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/mild_coughing_17_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_4-03.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_4-03.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_7-03.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_7-03.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_8-01.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_8-01.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_2_clip_1_03.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_2_clip_1_03.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_2_clip_2_03.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_2_clip_2_03.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_3_clip_1_03.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_3_clip_1_03.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_3_clip_2_03.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_3_clip_2_03.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_5_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_5_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_5_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_5_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_5_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_5_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_5_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_5_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_5_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_5_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_6_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_6_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_9_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_9_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_9_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_9_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_9_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_9_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_9_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_9_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_11_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_11_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_12_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_12_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_13_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_13_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_15_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_15_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_10_clip_14_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_10_clip_14_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_11_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_11_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_11_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_11_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_11_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_11_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_11_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_11_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_11_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_11_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_11_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_11_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_12_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_12_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_12_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_12_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_12_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_12_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_12_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_12_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_12_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_12_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_13_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_13_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_14_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_14_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_15_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_15_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_16_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_16_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_16_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_16_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_16_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_16_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_16_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_16_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_16_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_16_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_16_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_16_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_17_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_17_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/intense_coughing/intense_coughing_1-02.mp3 to /content/drive/MyDrive/coughing/wav_files/intense_coughing_1-02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_1_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_1_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_3_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_3_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_6_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_6_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_4_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_4_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_7_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_7_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_5_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_5_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_2_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_2_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_8_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_8_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_9_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_9_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_10_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_10_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_19_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_19_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_12_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_12_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_14_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_14_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_17_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_17_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_15_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_15_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_13_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_13_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_16_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_16_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_11_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_11_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_18_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_18_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_131_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_131_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_128_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_128_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_130_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_130_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_126_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_126_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_129_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_129_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_127_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_127_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_133_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_133_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_132_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_132_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_20_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_20_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_124_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_124_02.wav
# Converted /content/drive/MyDrive/coughing/normal_speech/normal_speech_clip_125_02.mp3 to /content/drive/MyDrive/coughing/wav_files/normal_speech_clip_125_02.wav
# Total files with .wav conversion problems: 0

# %% [markdown]
# Define function to save spectrogram as image

# %%
def save_spectrogram(spectrogram, file_path):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(spectrogram, sr=22050, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    plt.savefig(file_path, format='png')
    plt.close()

# %% [markdown]
# Define function to generate spectrograms

# %%
def generate_spectrograms(folder_path, spectrogram_folder):
    labels = []
    for sub_folder in ['normal_speech', 'mild_coughing', 'intense_coughing']:
        sub_folder_path = Path(folder_path) / sub_folder
        if not sub_folder_path.exists():
            print(f"Directory {sub_folder_path} does not exist, skipping.")
            continue

        for file_path in sub_folder_path.iterdir():
            if file_path.suffix.lower() == '.mp3':  # Assuming the audio files are in .wav format
                try:
                    audio, sr = librosa.load(file_path, sr=None)
                    spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)
                    log_spectrogram = librosa.power_to_db(spectrogram, ref=np.max)

                    # Save spectrogram as image
                    spectrogram_file_path = Path(spectrogram_folder) / f"{file_path.stem}.png"
                    save_spectrogram(log_spectrogram, spectrogram_file_path)

                    labels.append((spectrogram_file_path, sub_folder))
                except Exception as e:
                    print(f"Error loading {file_path}: {e}")
    return labels

# %% [markdown]
# Define function to create tf.data.Dataset

# %%
def create_dataset(spectrogram_labels, batch_size=32, img_size=(128, 128)):
    file_paths, labels = zip(*spectrogram_labels)

    # Encode labels
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(labels)
    categorical_labels = to_categorical(encoded_labels)

    def load_image(file_path, label):
        image = tf.io.read_file(file_path)
        image = tf.image.decode_png(image, channels=1)
        image = tf.image.resize(image, img_size)
        image = tf.image.per_image_standardization(image)
        return image, label

    dataset = tf.data.Dataset.from_tensor_slices((list(map(str, file_paths)), categorical_labels))
    dataset = dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(len(file_paths)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

    return dataset, label_encoder

# %% [markdown]
# Define function to load audio files and generate spectrograms

# %%
def load_audio_files(folder_path, spectrogram_folder):
    audio_files = []
    spectrogram_files = []

    # List audio files
    for sub_folder in ['normal_speech', 'mild_coughing', 'intense_coughing']:
        sub_folder_path = os.path.join(folder_path, sub_folder)
        print(f"Checking files in {sub_folder_path}")
        for file_name in os.listdir(sub_folder_path):
            file_path = os.path.join(sub_folder_path, file_name)
            if file_path.endswith('.wav'):
                audio_files.append(file_path)

    # List spectrogram files
    for sub_folder in ['normal_speech', 'mild_coughing', 'intense_coughing']:
        sub_folder_path = os.path.join(spectrogram_folder, sub_folder)
        print(f"Checking files in {sub_folder_path}")
        try:
            for file_name in os.listdir(sub_folder_path):
                file_path = os.path.join(sub_folder_path, file_name)
                if file_path.endswith('.png'):  # Assuming spectrograms are in .png format
                    spectrogram_files.append(file_path)
        except FileNotFoundError:
            print(f"Error: Directory '{sub_folder_path}' not found.")
            continue

    # Return data
    return audio_files, spectrogram_files

# %% [markdown]
# Define function to preprocess the data

# %%
def preprocess_data(audio_data, labels):
    # Pad/truncate spectrograms to the same size
    max_shape = (128, 128)  # Example size
    processed_data = []
    for spec in audio_data:
        if spec.shape[1] < max_shape[1]:
            spec = np.pad(spec, ((0, 0), (0, max_shape[1] - spec.shape[1])), mode='constant')
        else:
            spec = spec[:, :max_shape[1]]
        processed_data.append(spec)
    processed_data = np.array(processed_data)

    # Expand dimensions to add the channel (needed for CNN)
    processed_data = np.expand_dims(processed_data, axis=-1)

    # Encode labels
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(labels)
    categorical_labels = to_categorical(encoded_labels)

    return processed_data, categorical_labels, label_encoder

# %% [markdown]
# Define function to build the CNN model

# %%
def build_cnn_model(input_shape, num_classes):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')  # Number of output classes
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# Define main function to execute the entire workflow

# %%
def main():
    folder_path = '/content/drive/MyDrive/coughing'  # Update to your audio files folder
    spectrogram_folder = '/content/drive/MyDrive/coughing/spectrogram'  # Update to your spectrogram folder

    # Create spectrogram directories if they do not exist
    for sub_folder in ['normal_speech', 'mild_coughing', 'intense_coughing']:
        sub_folder_path = os.path.join(spectrogram_folder, sub_folder)
        if not os.path.exists(sub_folder_path):
            try:
                os.makedirs(sub_folder_path)
            except OSError as e:
                print(f"Error creating directory '{sub_folder_path}': {e}")

    try:
        audio_files, spectrogram_files = load_audio_files(folder_path, spectrogram_folder)
    except Exception as e:
        print(f"Error loading data: {e}")
        return

    if not audio_files or not spectrogram_files:
        print("Error: No valid audio or spectrogram files found.")
        return

    # Print or check loaded files for verification
    print(f"Found {len(audio_files)} audio files and {len(spectrogram_files)} spectrogram files.")
    print("Sample audio file:", audio_files[0])  # Print a sample file for verification

if __name__ == "__main__":
    main()
# Out:
# Checking files in /content/drive/MyDrive/coughing/normal_speech
# Checking files in /content/drive/MyDrive/coughing/mild_coughing
# Checking files in /content/drive/MyDrive/coughing/intense_coughing
# Checking files in /content/drive/MyDrive/coughing/spectrogram/normal_speech
# Checking files in /content/drive/MyDrive/coughing/spectrogram/mild_coughing
# Checking files in /content/drive/MyDrive/coughing/spectrogram/intense_coughing
# Error: No valid audio or spectrogram files found.
